# %%
pip install pylsl
# Out:
# Requirement already satisfied: pylsl in /opt/homebrew/anaconda3/lib/python3.10/site-packages (1.16.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyqtgraph
# Out:
# Requirement already satisfied: pyqtgraph in /opt/homebrew/anaconda3/lib/python3.10/site-packages (0.13.3)
# Requirement already satisfied: numpy>=1.20.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from pyqtgraph) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""Example program to demonstrate how to read a multi-channel time-series
from LSL in a chunk-by-chunk manner (which is more efficient)."""

from pylsl import StreamInlet, resolve_stream
import numpy as np

chunk_size = 150 # 150 samples
sample_counter = 0
buffer = []

if __name__ == '__main__':
    # first resolve an EEG stream on the lab network
    print("looking for an EMG stream...")
    streams = resolve_stream('type', 'EMG_chunk')

    # create a new inlet to read from the stream
    inlet = StreamInlet(streams[0])

    while True:
        # get a new sample (you can also omit the timestamp part if you're not
        # interested in it)
        chunk, timestamps = inlet.pull_chunk()
        if timestamps:
            samples = np.array(chunk)
            sample_counter = sample_counter + samples.shape[0]
            buffer.append(samples)
            print(samples.shape)
        
        # Do something when buffer is full
        if sample_counter == chunk_size:
            # Concat list into single np array
            data = np.concatenate((buffer), axis=0)
            print(data.shape)
            print('=====================================')
            
            sample_counter = 0 # reset counter
            buffer = [] # reset buffer
# Out:
# looking for an EMG stream...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 17
#      14 streams = resolve_stream('type', 'EMG_chunk')
#      16 # create a new inlet to read from the stream
# ---> 17 inlet = StreamInlet(streams[0])
#      19 while True:
#      20     # get a new sample (you can also omit the timestamp part if you're not
#      21     # interested in it)
#      22     chunk, timestamps = inlet.pull_chunk()
#
# IndexError: list index out of range

# %%
#!/usr/bin/env python
"""
ReceiveAndPlot example for LSL

This example shows data from all found outlets in realtime.
It illustrates the following use cases:
- efficiently pulling data, re-using buffers
- automatically discarding older samples
- online postprocessing
"""

import numpy as np
import math
import pylsl

# Import PyQt5 modules directly, replacing the problematic import.
# Note: You might need to adjust this based on whether you're using PyQt5 or PySide2.
from PyQt5 import QtWidgets, QtCore
import pyqtgraph as pg

from pyqtgraph.Qt import QtCore, QtGui
from typing import List

# Basic parameters for the plotting window
plot_duration = 5  # how many seconds of data to show
update_interval = 60  # ms between screen updates
pull_interval = 500  # ms between each pull operation


class Inlet:
    """Base class to represent a plottable inlet"""
    def __init__(self, info: pylsl.StreamInfo):
        # create an inlet and connect it to the outlet we found earlier.
        # max_buflen is set so data older the plot_duration is discarded
        # automatically and we only pull data new enough to show it

        # Also, perform online clock synchronization so all streams are in the
        # same time domain as the local lsl_clock()
        # (see https://labstreaminglayer.readthedocs.io/projects/liblsl/ref/enums.html#_CPPv414proc_clocksync)
        # and dejitter timestamps
        self.inlet = pylsl.StreamInlet(info, max_buflen=plot_duration,
                                       processing_flags=pylsl.proc_clocksync | pylsl.proc_dejitter)
        # store the name and channel count
        self.name = info.name()
        self.channel_count = info.channel_count()

    def pull_and_plot(self, plot_time: float, plt: pg.PlotItem):
        """Pull data from the inlet and add it to the plot.
        :param plot_time: lowest timestamp that's still visible in the plot
        :param plt: the plot the data should be shown on
        """
        # We don't know what to do with a generic inlet, so we skip it.
        pass


class DataInlet(Inlet):
    """A DataInlet represents an inlet with continuous, multi-channel data that
    should be plotted as multiple lines."""
    dtypes = [[], np.float32, np.float64, None, np.int32, np.int16, np.int8, np.int64]

    def __init__(self, info: pylsl.StreamInfo, plt: pg.PlotItem):
        super().__init__(info)
        # calculate the size for our buffer, i.e. two times the displayed data
        bufsize = (2 * math.ceil(info.nominal_srate() * plot_duration), info.channel_count())
        self.buffer = np.empty(bufsize, dtype=self.dtypes[info.channel_format()])
        empty = np.array([])
        # create one curve object for each channel/line that will handle displaying the data
        self.curves = [pg.PlotCurveItem(x=empty, y=empty, autoDownsample=True) for _ in range(self.channel_count)]
        for curve in self.curves:
            plt.addItem(curve)

    def pull_and_plot(self, plot_time, plt):
        # pull the data
        _, ts = self.inlet.pull_chunk(timeout=0.0,
                                      max_samples=self.buffer.shape[0],
                                      dest_obj=self.buffer)
        # ts will be empty if no samples were pulled, a list of timestamps otherwise
        if ts:
            ts = np.asarray(ts)
            y = self.buffer[0:ts.size, :]
            this_x = None
            old_offset = 0
            new_offset = 0
            for ch_ix in range(self.channel_count):
                # we don't pull an entire screen's worth of data, so we have to
                # trim the old data and append the new data to it
                old_x, old_y = self.curves[ch_ix].getData()
                # the timestamps are identical for all channels, so we need to do
                # this calculation only once
                if ch_ix == 0:
                    # find the index of the first sample that's still visible,
                    # i.e. newer than the left border of the plot
                    old_offset = old_x.searchsorted(plot_time)
                    # same for the new data, in case we pulled more data than
                    # can be shown at once
                    new_offset = ts.searchsorted(plot_time)
                    # append new timestamps to the trimmed old timestamps
                    this_x = np.hstack((old_x[old_offset:], ts[new_offset:]))
                # append new data to the trimmed old data
                this_y = np.hstack((old_y[old_offset:], y[new_offset:, ch_ix] - ch_ix))
                # replace the old data
                self.curves[ch_ix].setData(this_x, this_y)


class MarkerInlet(Inlet):
    """A MarkerInlet shows events that happen sporadically as vertical lines"""
    def __init__(self, info: pylsl.StreamInfo):
        super().__init__(info)

    def pull_and_plot(self, plot_time, plt):
        # TODO: purge old markers
        strings, timestamps = self.inlet.pull_chunk(0)
        if timestamps:
            for string, ts in zip(strings, timestamps):
                plt.addItem(pg.InfiniteLine(ts, angle=90, movable=False, label=string[0]))


def main():
    # firstly resolve all streams that could be shown
    inlets: List[Inlet] = []
    print("looking for streams")
    streams = pylsl.resolve_streams()

    # Create the pyqtgraph window
    pw = pg.plot(title='LSL Plot')
    plt = pw.getPlotItem()
    plt.enableAutoRange(x=False, y=True)

    # iterate over found streams, creating specialized inlet objects that will
    # handle plotting the data
    for info in streams:
        if info.type() == 'Markers':
            if info.nominal_srate() != pylsl.IRREGULAR_RATE \
                    or info.channel_format() != pylsl.cf_string:
                print('Invalid marker stream ' + info.name())
            print('Adding marker inlet: ' + info.name())
            inlets.append(MarkerInlet(info))
        elif info.nominal_srate() != pylsl.IRREGULAR_RATE \
                and info.channel_format() != pylsl.cf_string:
            print('Adding data inlet: ' + info.name())
            inlets.append(DataInlet(info, plt))
        else:
            print('Don\'t know what to do with stream ' + info.name())

    def scroll():
        """Move the view so the data appears to scroll"""
        # We show data only up to a timepoint shortly before the current time
        # so new data doesn't suddenly appear in the middle of the plot
        fudge_factor = pull_interval * .002
        plot_time = pylsl.local_clock()
        pw.setXRange(plot_time - plot_duration + fudge_factor, plot_time - fudge_factor)

    def update():
        # Read data from the inlet. Use a timeout of 0.0 so we don't block GUI interaction.
        mintime = pylsl.local_clock() - plot_duration
        # call pull_and_plot for each inlet.
        # Special handling of inlet types (markers, continuous data) is done in
        # the different inlet classes.
        for inlet in inlets:
            inlet.pull_and_plot(mintime, plt)

    # create a timer that will move the view every update_interval ms
    update_timer = QtCore.QTimer()
    update_timer.timeout.connect(scroll)
    update_timer.start(update_interval)

    # create a timer that will pull and add new data occasionally
    pull_timer = QtCore.QTimer()
    pull_timer.timeout.connect(update)
    pull_timer.start(pull_interval)

    import sys

    # Start Qt event loop unless running in interactive mode or using pyside.
    if (sys.flags.interactive != 1) or not hasattr(QtCore, 'PYQT_VERSION'):
        QtWidgets.QApplication.instance().exec_()


if __name__ == '__main__':
    main()
# Out:
# looking for streams
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:102   INFO| 	IPv4 addr: 7f000001
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: ::1
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::1%lo0
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'gif0' (status: 0, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'stf0' (status: 0, multicast: 0, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'anpi0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'anpi1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'en3' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'en4' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'en1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'en2' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'bridge0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'ap1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'ap1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::3c91:80ff:fef3:7219%ap1
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.466s) [          362967]      netinterfaces.cpp:102   INFO| 	IPv4 addr: c0a801f1
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::502d:1ff:fe27:a4c6%awdl0
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::502d:1ff:fe27:a4c6%llw0
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::c0a4:de63:abea:325d%utun0
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::79b6:93b9:3f3c:a12b%utun1
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::ce81:b1c:bd2c:69e%utun2
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::2010:99f:88c3:d1c3%utun3
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::e1ac:fe72:af70:2989%utun4
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::629c:15b0:623b:8639%utun5
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun6' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun6' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::a606:379e:9adc:248e%utun6
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun7' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:91    INFO| netif 'utun7' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-03 23:36:40.917 (   0.467s) [          362967]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::66f0:3d5:249c:6739%utun7
# 2024-03-03 23:36:40.918 (   0.467s) [          362967]         api_config.cpp:271   INFO| Loaded default config
# Adding data inlet: obci_eeg1
# 2024-03-03 23:36:42.502 (   2.052s) [          362967]             common.cpp:66    INFO| git:v1.16.2-23-g6a85d6f9/branch:master/build:Release/compiler:AppleClang-15.0.0.15000040/link:SHARED
# 2024-03-04 13:54:56.692 (51498.331s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 13:55:11.900 (51513.420s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:13:12.981 (52594.524s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:13:27.997 (52609.541s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:13:43.009 (52624.553s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:13:58.020 (52639.564s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:14:13.032 (52654.577s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:14:28.039 (52669.584s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:14:43.053 (52684.598s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:14:58.066 (52699.612s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:15:13.079 (52714.625s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:30:53.023 (53654.597s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:31:32.938 (53694.523s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:31:47.944 (53709.533s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:32:02.954 (53724.545s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:47:42.910 (54664.537s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:47:57.911 (54679.542s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:48:12.925 (54694.557s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:56:36.574 (55198.226s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:56:51.587 (55213.239s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 14:57:06.599 (55228.252s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:02:14.109 (55535.773s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:02:29.135 (55550.799s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:02:44.147 (55565.812s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:07:14.321 (55836.001s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:07:29.325 (55851.014s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:07:44.333 (55866.027s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:08:39.257 (55920.954s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:08:54.266 (55935.964s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:09:09.277 (55950.976s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:09:28.418 (55970.119s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:09:43.428 (55985.130s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:09:58.429 (56000.131s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:11:04.130 (56065.835s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:11:19.142 (56080.847s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:11:34.151 (56095.857s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:11:49.162 (56110.869s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:20:12.356 (56614.087s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:20:27.363 (56629.094s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:20:42.372 (56644.104s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:20:57.377 (56659.110s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:22:05.387 (56727.123s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:22:20.393 (56742.129s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:22:35.405 (56757.143s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:25:20.669 (56922.414s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:41:00.609 (57862.390s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:41:15.631 (57877.404s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:41:30.647 (57892.418s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:42:29.926 (57951.697s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:42:44.939 (57966.710s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:42:59.952 (57981.724s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:58:39.917 (58921.724s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:58:54.930 (58936.739s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 15:59:09.937 (58951.746s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:04:09.690 (59251.512s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:04:24.699 (59266.521s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:04:39.708 (59281.530s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:20:19.669 (60221.528s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:20:34.678 (60236.539s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:21:14.607 (60276.471s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:21:29.613 (60291.478s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:21:44.627 (60306.492s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:37:24.584 (61246.491s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:37:39.591 (61261.505s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:37:54.593 (61276.510s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:53:34.549 (62216.512s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:53:49.566 (62231.533s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 16:54:04.568 (62246.535s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:09:44.542 (63186.555s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:09:59.563 (63201.563s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:10:14.579 (63216.573s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:10:47.902 (63249.896s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:11:02.912 (63264.905s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:11:17.939 (63279.933s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:11:32.945 (63294.940s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:11:54.848 (63316.843s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:12:09.860 (63331.856s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:12:24.867 (63346.863s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:12:41.968 (63363.965s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:12:56.980 (63378.977s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:13:11.986 (63393.984s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:15:01.510 (63503.512s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:15:16.518 (63518.521s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:15:31.532 (63533.536s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:16:04.867 (63566.872s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:16:19.878 (63581.884s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:16:34.892 (63596.898s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:17:31.780 (63653.789s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:17:47.014 (63669.023s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:18:02.086 (63684.096s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:18:17.096 (63699.106s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:18:32.111 (63714.121s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:18:47.114 (63729.125s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:19:02.120 (63744.132s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:19:17.128 (63759.140s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:19:32.135 (63774.148s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:19:47.143 (63789.157s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:25:33.587 (64135.614s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:25:48.617 (64150.644s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:26:03.628 (64165.656s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:26:18.640 (64180.669s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:26:53.342 (64215.371s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:27:08.351 (64230.381s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:27:23.364 (64245.395s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:27:38.440 (64260.471s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:27:53.449 (64275.481s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:28:08.458 (64290.490s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:29:10.183 (64352.218s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:29:25.187 (64367.222s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:29:40.200 (64382.236s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:29:55.210 (64397.247s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:31:00.539 (64462.578s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:31:15.554 (64477.594s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:31:30.560 (64492.600s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:36:09.324 (64771.377s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
# 2024-03-04 17:36:24.335 (64786.387s) [W_obci_eeg1     ]   inlet_connection.cpp:226    ERR| A recovery attempt encountered an unexpected error: set_option: Can't assign requested address
